# %% [markdown]
# <a href="https://colab.research.google.com/github/mchen899923/visualization_assignment/blob/main/assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment: Visualization
# ### `! git clone https://github.com/ds3001f25/visualization_assignment.git`
# ### Do Q1 and Q2.

# %% [markdown]
# **Q1.** Write your own function to make a kernel density plot.
#
# - The user should pass in a Pandas series or Numpy array.
# - The default kernel should be Gaussian, but include the uniform/bump and Epanechnikov as alternatives.
# - The default bandwidth should be the Silverman plug-in, but allow the user to specify an alternative.
# - You can use Matplotlib or Seaborn's `.lineplot`, but not an existing function that creates kernel density plots.
#
# You will have to make a lot of choices and experiment with getting errors. Embrace the challenge and track your choices in the comments in your code.
#
# Use the pretrail data set from class to show that your function works, and compare it with the Seaborn `kdeplot`.
#
# We covered the Gaussian,
# $$
# k(z) = \dfrac{1}{\sqrt{2\pi}}e^{-z^2/2}
# $$
# and uniform
# $$
# k(z) = \begin{cases}
# \frac{1}{2}, & |z| \le 1 \\
# 0, & |z|>1
# \end{cases}
# $$
# kernels in class, but the Epanechnikov kernel is
# $$
# k(z) = \begin{cases}
# \frac{3}{4} (1-z^2), & |z| \le 1 \\
# 0, & |z|>1.
# \end{cases}
# $$
#
# In order to make your code run reasonably quickly, consider using the `pdist` or `cdist` functions from SciPy to make distance calculations for arrays of points. The other leading alternative is to thoughtfully use NumPy's broadcasting features. Writing `for` loops will be slow, but that's fine.

# %% [markdown]
# **Q2.** This question provides some practice doing exploratory data analysis and visualization.
#
# The "relevant" variables for this question are:
#   - `level` - Level of institution (4-year, 2-year)
#   - `aid_value` - The average amount of student aid going to undergraduate recipients
#   - `control` - Public, Private not-for-profit, Private for-profit
#   - `grad_100_value` - percentage of first-time, full-time, degree-seeking undergraduates who complete a degree or certificate program within 100 percent of expected time (bachelor's-seeking group at 4-year institutions)
#
# 1. Load the `./data/college_completion.csv` data with Pandas.
# 2. What are are the dimensions of the data? How many observations are there? What are the variables included? Use `.head()` to examine the first few rows of data.
# 3. Cross tabulate `control` and `level`. Describe the patterns you see.
# 4. For `grad_100_value`, create a histogram, kernel density plot, boxplot, and statistical description.
# 5. For `grad_100_value`, create a grouped kernel density plot by `control` and by `level`. Describe what you see. Use `groupby` and `.describe` to make grouped calculations of statistical descriptions of `grad_100_value` by `level` and `control`. Which institutions appear to have the best graduation rates?
# 6. Create a new variable, `df['levelXcontrol']=df['level']+', '+df['control']` that interacts level and control. Make a grouped kernel density plot. Which institutions appear to have the best graduation rates?
# 7. Make a kernel density plot of `aid_value`. Now group your graph by `level` and `control`. What explains the shape of the graph? Use `groupby` and `.describe` to make grouped calculations of statistical descriptions of `aid_value` by `level` and `control`.
# 8. Make a scatterplot of `grad_100_value` by `aid_value`. Describe what you see. Now make the same plot, grouping by `level` and then `control`. Describe what you see. For which kinds of institutions does aid seem to increase graduation rates?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2.1

# %%
college_completion_df = pd.read_csv("college_completion.csv") #loaded the data with Pandas
college_completion_df
# Out:
#       index  unitid                                chronname             city  \
# 0         0  100654                   Alabama A&M University           Normal
# 1         1  100663      University of Alabama at Birmingham       Birmingham
# 2         2  100690                       Amridge University       Montgomery
# 3         3  100706      University of Alabama at Huntsville       Huntsville
# 4         4  100724                 Alabama State University       Montgomery
# ...     ...     ...                                      ...              ...
# 3793   3793  461528                Grace College of Divinity     Fayetteville
# 3794   3794  462354  John Paul the Great Catholic University        Escondido
# 3795   3795  466921  Chamberlain College of Nursing-Missouri        St. Louis
# 3796   3796  474881              Minneapolis Media Institute            Edina
# 3797   3797  475291            Brown College-Brooklyn Center  Brooklyn Center
#
# ...

# %% [markdown]
# 2.2

# %%
print(college_completion_df.shape) #dimensions of the data are (3798,  63)

number_of_observations = college_completion_df.shape[0]
print(number_of_observations) #number of observations is 3798

print(college_completion_df.columns) #included variables 'index', 'unitid', 'chronname', 'city', 'state', 'level', 'control',
       #'basic', 'hbcu', 'flagship', 'long_x', 'lat_y', 'site', 'student_count',
       #'awards_per_value', 'awards_per_state_value', 'awards_per_natl_value',
       #'exp_award_value', 'exp_award_state_value', 'exp_award_natl_value',
       #'exp_award_percentile', 'ft_pct', 'fte_value', 'fte_percentile',
       #'med_sat_value', 'med_sat_percentile', 'aid_value', 'aid_percentile',
       #'endow_value', 'endow_percentile', 'grad_100_value',
       #'grad_100_percentile', 'grad_150_value', 'grad_150_percentile',
       #'pell_value', 'pell_percentile', 'retain_value', 'retain_percentile',
       #'ft_fac_value', 'ft_fac_percentile', 'vsa_year',
       #'vsa_grad_after4_first', 'vsa_grad_elsewhere_after4_first',
       #'vsa_enroll_after4_first', 'vsa_enroll_elsewhere_after4_first',
       #'vsa_grad_after6_first', 'vsa_grad_elsewhere_after6_first',
       #'vsa_enroll_after6_first', 'vsa_enroll_elsewhere_after6_first',
       #'vsa_grad_after4_transfer', 'vsa_grad_elsewhere_after4_transfer',
       #'vsa_enroll_after4_transfer', 'vsa_enroll_elsewhere_after4_transfer',
       #'vsa_grad_after6_transfer', 'vsa_grad_elsewhere_after6_transfer',
       #'vsa_enroll_after6_transfer', 'vsa_enroll_elsewhere_after6_transfer',
       #'similar', 'state_sector_ct', 'carnegie_ct', 'counted_pct', 'nicknames',
       #'cohort_size'

college_completion_df.head() #first few rows of data
# Out:
# (3798, 63)
# 3798
# Index(['index', 'unitid', 'chronname', 'city', 'state', 'level', 'control',
#        'basic', 'hbcu', 'flagship', 'long_x', 'lat_y', 'site', 'student_count',
#        'awards_per_value', 'awards_per_state_value', 'awards_per_natl_value',
#        'exp_award_value', 'exp_award_state_value', 'exp_award_natl_value',
#        'exp_award_percentile', 'ft_pct', 'fte_value', 'fte_percentile',
#        'med_sat_value', 'med_sat_percentile', 'aid_value', 'aid_percentile',
#        'endow_value', 'endow_percentile', 'grad_100_value',
#        'grad_100_percentile', 'grad_150_value', 'grad_150_percentile',
#        'pell_value', 'pell_percentile', 'retain_value', 'retain_percentile',
#        'ft_fac_value', 'ft_fac_percentile', 'vsa_year',
#        'vsa_grad_after4_first', 'vsa_grad_elsewhere_after4_first',
#        'vsa_enroll_after4_first', 'vsa_enroll_elsewhere_after4_first',
#        'vsa_grad_after6_first', 'vsa_grad_elsewhere_after6_first',
# ...

# %% [markdown]
# 2.3

# %% [markdown]
# I've noticed that there tend to be more 4-year private not-for-profit institutions than any other institutions. There tend to be less 2-year private not-for-profit institutions than any other institutions.

# %%
pd.crosstab(college_completion_df["control"], college_completion_df["level"]) #cross tab of control and level
# Out:
# level                   2-year  4-year
# control
# Private for-profit         465     527
# Private not-for-profit      68    1180
# Public                     926     632

# %% [markdown]
# 2.4

# %%
college_completion_df["grad_100_value"].hist(bins=20, grid=False) #histogram
# Out:
# <Axes: >

# %%
var = "grad_100_value"
college_completion_df[var].plot.density() #kernel density plot
# Out:
# <Axes: ylabel='Density'>

# %%
college_completion_df["grad_100_value"].plot.box() #box plot
# Out:
# <Axes: >

# %%
descr = college_completion_df["grad_100_value"].describe() #Describe grad_100_value and save as an object
print(descr, '\n')
# Out:
# count    3467.000000
# mean       28.364465
# std        23.312730
# min         0.000000
# 25%         9.000000
# 50%        22.500000
# 75%        43.650000
# max       100.000000
# Name: grad_100_value, dtype: float64

# %%
std = descr["std"] #computing variance
var = std**2
print("Variance: ", var, '\n')
# Out:
# Variance:  543.483382020338

# %%
#Computing IQR
thirdQ = descr["75%"] #75% percentile
firstQ = descr["25%"] #25% percentile
IQR = thirdQ - firstQ #IQR
print("IQR: ", IQR)
# Out:
# IQR:  34.650000000000006

# %% [markdown]
# 2.5

# %% [markdown]
# For the KDE plot for level, I noticed that there tend to be more graduates for the 4-year institutions. For the 2-year institution, there tends to be a higher peak. For the KDE plot for control, I noticed more private, not-for-profit institutions have higher graduation rates.

# %%
sns.kdeplot(data = college_completion_df, x = "grad_100_value", hue = "level", fill = True) #KDE plot for level
plt.show() #generate KDE plot
sns.kdeplot(data=college_completion_df, x = "grad_100_value", hue = "control", fill = True) #KDE plot for control
plt.show() #generate KDE plot

# %% [markdown]
# I've noticed that 2-year public institutions have the highest count for the grad_100_value among 2-year institutions, showing a higher graduation rate. However, 4-year private not-for-profit schools have the highest count out of all the institutions, showing they have the highest graduation rate of all time.

# %%
statistical_description = college_completion_df.groupby(["level", "control"])["grad_100_value"].describe() #description of grad_100_value grouped by level and control
statistical_description
# Out:
#                                 count       mean        std  min     25%  \
# level  control
# 2-year Private for-profit       461.0  37.197614  25.497380  0.0  15.800
#        Private not-for-profit    68.0  41.913235  28.348302  0.0  16.225
#        Public                   926.0  12.400000  10.893600  0.0   5.100
# 4-year Private for-profit       318.0  17.382704  20.788525  0.0   0.000
#        Private not-for-profit  1121.0  41.645674  23.243453  0.0  25.000
#        Public                   573.0  25.561082  16.403902  0.0  13.600
#
#                                 50%     75%    max
# level  control
# 2-year Private for-profit      33.9  57.800  100.0
#        Private not-for-profit  44.4  61.200  100.0
#        Public                   9.4  16.175   97.8
# 4-year Private for-profit      12.5  26.325  100.0
#        Private not-for-profit  41.0  57.800  100.0
#        Public                  21.8  33.800   86.3

# %% [markdown]
# 2.6

# %% [markdown]
# 2-year, public institutions tend to have the highest, and thus the best, graduation rates.

# %%
college_completion_df["levelXcontrol"] = college_completion_df["level"]+', '+college_completion_df["control"]

conditioning = "levelXcontrol"
var = "grad_100_value"
sns.kdeplot(data = college_completion_df, x = var, hue = conditioning, common_norm = False).set(title = "Grouped KDE plot of grad_100_value grouped by levelXcontrol")
# Out:
# [Text(0.5, 1.0, 'Grouped KDE plot of grad_100_value grouped by levelXcontrol')]

# %% [markdown]
# 2.7

# %% [markdown]
# I think a similar amount of aid is provided for all types of 2-year institutions, leading to the similar peaks. For 4-year institutions, more aid is provided for private not-for-profit institutions, leading to a flatter curve. Less aid is provided for 4-year, private for-profit instituions, leading to sharper peak with a lower median.

# %%
sns.kdeplot(data = college_completion_df, x = "aid_value", hue = "levelXcontrol", fill = True) #generates aid_value grouped by levelxcontrol
plt.show()

# %%
statistical_descriptions = college_completion_df.groupby(["level", "control"])["aid_value"].describe() #description of aid_value grouped by level and control
statistical_descriptions
# Out:
#                                 count          mean          std     min  \
# level  control
# 2-year Private for-profit       464.0   4559.681034  1286.688269   294.0
#        Private not-for-profit    68.0   5128.058824  2590.449946   934.0
#        Public                   926.0   4126.199784  1260.271382   881.0
# 4-year Private for-profit       527.0   4696.062619  1489.410020  1580.0
#        Private not-for-profit  1180.0  14702.401695  7649.775203   902.0
#        Public                   632.0   6514.071203  2353.716693  2232.0
#
#                                    25%      50%       75%      max
# level  control
# 2-year Private for-profit      3818.75   4286.5   5122.00   9727.0
#        Private not-for-profit  3650.00   4516.5   6311.50  13654.0
#        Public                  3311.25   3943.5   4762.00   9809.0
# 4-year Private for-profit      3885.50   4364.0   5131.50  18355.0
#        Private not-for-profit  9113.25  13774.5  18996.75  41580.0
# ...

# %% [markdown]
# 2.8

# %% [markdown]
# I noticed that this scatterplot tends to have less people graduate with less aid. There are more people who graduated with more aid, but it's less data points. This means that there are less people who got aid in general. Overall, there seems to be a positive correlation.

# %%
college_completion_df.plot.scatter(x = "grad_100_value", y = "aid_value") #scatterplot
# Out:
# <Axes: xlabel='grad_100_value', ylabel='aid_value'>

# %% [markdown]
# I've noticed a higher graduation rate for 4-year instituions, with a positive upward trend. I've noticed the same positive upward trend for private, not-for-profit institutions. Overall, it seems as though increasing aid values helps graduation rates at those two institutions more.

# %%
sns.scatterplot(data=college_completion_df, x = "grad_100_value", y = "aid_value", hue = "level") #scatterplot of level
plt.legend(loc = "upper right",bbox_to_anchor = (1.25, 1)) #legend box location
plt.show()
sns.scatterplot(data=college_completion_df, x = "grad_100_value", y = "aid_value", hue = "control") #scatterplot of control
plt.legend(loc = "upper right",bbox_to_anchor=(1.45, 1))
plt.show()
